# %%
class Result:
    
    threads = -1
    symbol_size = -1
    symbols = -1
    results = list()
    def __init__(self, arr):
        self.threads = (arr[0].split(','))[3]
        self.symbols = (arr[0].split(','))[4]
        self.symbol_size = (arr[0].split(','))[5]  
        self.__get_results(arr)
        
    def __get_results(self, arr):
        for entry in arr:
            self.results.append(
            {'start_time': int((entry.split(','))[0]),
             'end_time': int((entry.split(','))[1])
            })
            
        print len(self.results)
            
    def average(self,unit=None):
        result = 0
        for entry in self.results:
            result = result + (entry.get('end_time') - entry.get('start_time'))
            # print result
        result = float(result) / len(self.results)
        if unit is None:
            return result
        elif unit == 'ms':
            return result / 1000
        
    def max(self, unit=None):
        values = list()
        for entry in self.results:
            values.append(entry.get('end_time') - entry.get('start_time'))
            
        if unit == None:
            return max(values)
        elif unit == 'ms':
            return float(max(values))/1000
    
    def min(self, unit=None):
        values = list()
        for entry in self.results:
            values.append(entry.get('end_time') - entry.get('start_time'))

        if unit == None:
            return max(values)
        elif unit == 'ms':
            return float(max(values))/1000
        

def read_file(file_name):
    with open(file_name) as file:
        content = file.readlines()
    content = [line.strip() for line in content]
    return content

res = Result(read_file('../results/simple_encoder/1524667602_simple_encoder_benchmark_8_8_67108864'))
res1 = Result(read_file('../results/simple_encoder/1524659171_simple_encoder_benchmark_8_16_33554432'))
res2 = Result(read_file('../results/simple_encoder/1524684183_simple_encoder_benchmark_8_32_16777216'))
res3 = Result(read_file('../results/simple_encoder/1524675890_simple_encoder_benchmark_8_64_8388608'))
res4 = Result(read_file('../results/simple_encoder/1524692593_simple_encoder_benchmark_8_128_4194304'))
res5 = Result(read_file('../results/simple_encoder/1524650729_simple_encoder_benchmark_8_256_2097152'))

print res.average(unit='ms')
print res.min(unit='ms')
print res.max(unit='ms')

print res1.average(unit='ms')
print res.min(unit='ms')
print res.max(unit='ms')

print res2.average(unit='ms')
print res3.average(unit='ms')
print res4.average(unit='ms')
print res5.average(unit='ms')
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 188.808825333
# 316.398
# 316.398
# 188.808825333
# 316.398
# 316.398
# 188.808825333
# 188.808825333
# 188.808825333
# 188.808825333
